# %% [markdown]
# ## Data Viz

# %%
# !pip install 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# libraries
import pandas as pd

# %%
lepo_df = pd.read_csv("/Users/sefika/projects/lm_embeddings_4_species/data/lepidoptera_taxa_with_old_names.csv")
lepo_df.head()

only_synonyms_lepo = lepo_df[lepo_df["oldSpeciesTaxonomicStatus"] == "SYNONYM"]
only_synonyms_lepo.head()
only_synonyms_lepo.info()
only_synonyms_lepo["oldSpeciesTaxonomicStatus"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1482 entries, 1 to 1674
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   key                            1482 non-null   int64
#  1   scientificName                 1482 non-null   str
#  2   canonicalName                  1482 non-null   str
#  3   rank                           1482 non-null   str
#  4   taxonomicStatus                1482 non-null   str
#  5   kingdom                        1482 non-null   str
#  6   phylum                         1482 non-null   str
#  7   class                          1482 non-null   str
#  8   order                          1482 non-null   str
#  9   family                         1482 non-null   str
#  10  genus                          1482 non-null   str
#  11  species                        1482 non-null   str
#  12  numDescendants                 1482 non-null   int64
# ...

# %%
coleop_df = pd.read_csv("/Users/sefika/projects/lm_embeddings_4_species/data/coleoptera_taxa_with_old_names.csv")
coleop_df.head()
only_synonyms_coleop = coleop_df[coleop_df["oldSpeciesTaxonomicStatus"] == "SYNONYM"]
only_synonyms_coleop.head()
only_synonyms_coleop.info()
only_synonyms_coleop["oldSpeciesTaxonomicStatus"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# Index: 273 entries, 0 to 732
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   key                            273 non-null    int64
#  1   scientificName                 273 non-null    str
#  2   canonicalName                  273 non-null    str
#  3   rank                           273 non-null    str
#  4   taxonomicStatus                273 non-null    str
#  5   kingdom                        273 non-null    str
#  6   phylum                         273 non-null    str
#  7   class                          273 non-null    str
#  8   order                          273 non-null    str
#  9   family                         269 non-null    str
#  10  genus                          273 non-null    str
#  11  species                        273 non-null    str
#  12  numDescendants                 273 non-null    int64
# ...

# %%
only_synonyms_coleop.to_csv("/Users/sefika/projects/lm_embeddings_4_species/data/only_synonyms_coleop.csv", index=False)
only_synonyms_lepo.to_csv("/Users/sefika/projects/lm_embeddings_4_species/data/only_synonyms_lepo.csv", index=False)
